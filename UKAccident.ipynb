# %% [markdown]
# # UK Accident History

# %% [markdown]
# ## Data Import

# %% [markdown]
# ### Package Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import CSV files

# %%
accdnt_2005 = pd.read_csv('accidents_2005_to_2007.csv')
accdnt_2009 = pd.read_csv('accidents_2009_to_2011.csv')
accdnt_2012 = pd.read_csv('accidents_2012_to_2014.csv')
accdntTraffic = pd.read_csv('ukTrafficAADF.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accdnt_2005.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    Number_of_Casualties        Date  ...   \
# 0                     1  04/01/2005  ...
# ...

# %%
accdnt_2009.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200901BS70001                 524910                  180800  -0.201349
# 1  200901BS70002                 525050                  181040  -0.199248
# 2  200901BS70003                 526490                  177990  -0.179599
# 3  200901BS70004                 524800                  180300  -0.203110
# 4  200901BS70005                 526930                  177490  -0.173445
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.512273             1                  2                   2
# 1  51.514399             1                  2                   2
# 2  51.486668             1                  3                   2
# 3  51.507804             1                  2                   2
# 4  51.482076             1                  2                   2
#
#    Number_of_Casualties        Date  ...   \
# 0                     1  01/01/2009  ...
# ...

# %%
accdnt_2012.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...   \
# 0                     1  19/01/2012  ...
# ...

# %%
accdntTraffic.head()
# Out:
#    AADFYear    CP Estimation_method Estimation_method_detailed  \
# 0      2000  6007           Counted               Manual count
# 1      2000  6009           Counted               Manual count
# 2      2000  6035           Counted               Manual count
# 3      2000  6054           Counted               Manual count
# 4      2000  6055           Counted               Manual count
#
#                      Region LocalAuthority  Road RoadCategory  Easting  \
# 0  Yorkshire and the Humber      Rotherham    M1           TM   446000
# 1  Yorkshire and the Humber          Leeds  M621           TM   432150
# 2  Yorkshire and the Humber      Doncaster   M18           TM   466400
# 3  Yorkshire and the Humber     Calderdale   M62           TM   404000
# 4  Yorkshire and the Humber          Leeds   M62           TM   426000
#
#    Northing    ...    V2AxleRigidHGV V3AxleRigidHGV  V4or5AxleRigidHGV  \
# 0    389300    ...              5351            656                711
# ...

# %% [markdown]
# #### Columns specification

# %%
print(accdnt_2005.columns)
print(accdnt_2009.columns)
print(accdnt_2012.columns)
print(accdntTraffic.columns)
# Out:
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Year'],
#       dtype='object')
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
# ...

# %% [markdown]
# #### Merge year dataset to one

# %%
accdnt_All = pd.concat([accdnt_2005,accdnt_2009,accdnt_2012], ignore_index=True)
#accdnt_All.head()
print('Total number of records {}.'.format(accdnt_All.shape))
print('Total number of records in year 2005 {}.'.format(accdnt_2005.shape))
print('Total number of records in year 2009 {}.'.format(accdnt_2009.shape))
print('Total number of records in year 2012 {}.'.format(accdnt_2012.shape))
# Out:
# Total number of records (1504150, 33).
# Total number of records in year 2005 (570011, 33).
# Total number of records in year 2009 (469442, 33).
# Total number of records in year 2012 (464697, 33).

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# #### Urban vs Rural

# %%
UrbanRural = accdnt_All['Urban_or_Rural_Area'].value_counts()
UrbanRural.plot.pie(figsize=(8,8))
plt.show()

# %%
sns.barplot(x=UrbanRural.index, y=UrbanRural.values)
plt.xlabel('Rural or Urban')
plt.ylabel('Accident count')
plt.show()

# %% [markdown]
# #### Pie  Chart on Light Condition

# %%
lightCondition = accdnt_All['Light_Conditions'].value_counts()
lightCondition.plot.pie(figsize=(8,8))
plt.title('Light condition during accident')
plt.ylabel('')
plt.show()

# %%
f, ax = plt.subplots(figsize=(17,8))
sns.barplot(x=lightCondition.index, y=lightCondition.values,ax=ax)
plt.xlabel('Light Condition')
plt.ylabel('Accident count')
plt.show()

# %% [markdown]
# #### Year Wise accident Analysis

# %%
year = accdnt_All['Year'].value_counts()
year.plot.pie(figsize=(8,8))
plt.title('Year breakdown of accident')
plt.ylabel('')
plt.show()

# %%
f,ax = plt.subplots(figsize=(15, 8))
sns.barplot(x=year.index, y=year.values, ax=ax)
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### Accident Count due to Various Condition

# %%
import itertools
Vcondition=['Light_Conditions','Weather_Conditions', 'Road_Surface_Conditions','Special_Conditions_at_Site']
plt.subplots(figsize=(30,15))
length=len(Vcondition)
for i,j in itertools.zip_longest(Vcondition,range(length)):
    plt.subplot((length/2),2,j+1)
    plt.subplots_adjust(wspace=0.2,hspace=0.5)
    sns.countplot(i,data=accdnt_All)
    plt.title(i,size=20)
    plt.ylabel('')
    plt.xlabel('')
plt.show()

# %% [markdown]
# #### Junction Control

# %%
f,ax = plt.subplots(figsize=(15,8))
jControl=accdnt_All['Junction_Control'].dropna().value_counts()
sns.countplot(accdnt_All['Junction_Control'], ax=ax)
plt.show()

# %% [markdown]
# #### Check Accident on Days of week

# %%
f,ax= plt.subplots(figsize=(10,8))
Doweek = accdnt_All['Day_of_Week'].dropna().value_counts()
Doweek.plot.pie(autopct='%1.1f%%',colors=sns.color_palette('summer',10))
plt.title('Accident by day of week')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### Pedestrian Crossing Control

# %%
plt.subplots(figsize=(10,10))
PCHControl = accdnt_All['Pedestrian_Crossing-Human_Control'].dropna().value_counts()
PCHControl.plot.pie(autopct='%1.1f%%',colors=sns.color_palette('Paired',10))
plt.title('Human Control Pedestrian Crossing')
plt.ylabel('')
plt.show()

# %%
plt.subplots(figsize=(10,10))
PCPControl = accdnt_All['Pedestrian_Crossing-Physical_Facilities'].dropna().value_counts()
PCPControl.plot.pie(autopct='%1.1f%%',colors=sns.color_palette('Paired',10))
plt.title('Physical Facilities at Pedestrian Crossing')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### Police presence at Accident Scene

# %%
plt.subplots(figsize=(10,8))
PArrive=accdnt_All['Did_Police_Officer_Attend_Scene_of_Accident'].dropna().value_counts()
PArrive.plot.pie(autopct='%1.1f%%',colors=sns.color_palette('summer',10))
plt.ylabel('')
plt.title('Did Police arrive accident scene')
plt.show()

# %% [markdown]
# #### Severity of Accident

# %%
plt.subplots(figsize=(15,5))
AccSeverity = accdnt_All['Accident_Severity'].dropna().value_counts()
AccSeverity.plot.barh(color=sns.color_palette('RdBu_r',5))
plt.title('Severity of Accident')
plt.xlabel('Accident count')
plt.ylabel('Severity')
plt.show()

# %% [markdown]
# #### Check Speed limit with Casualty

# %%
plt.scatter(x=accdnt_All['Speed_limit'],y=accdnt_All['Number_of_Casualties'],data=accdnt_All,c='red')
plt.scatter(x=accdnt_All['Speed_limit'],y=accdnt_All['Number_of_Vehicles'],data=accdnt_All,c='green')
plt.show()

# %% [markdown]
# #### Accident on Road Type

# %%
plt.subplots(figsize=(10,8))
PArrive=accdnt_All['Road_Type'].dropna().value_counts()
PArrive.plot.pie(autopct='%1.1f%%',colors=sns.color_palette('winter_r',10))
plt.ylabel('')
plt.title('Road Type')
plt.show()

# %%
col = ['Police_Force', 'Accident_Severity','Number_of_Vehicles', 'Number_of_Casualties']
plt.subplots(figsize=(30,15))
length=len(col)
for i,j in itertools.zip_longest(col,range(length)):
    plt.subplot((length/2),2,j+1)
    plt.subplots_adjust(wspace=0.2,hspace=0.5)
    sns.countplot(i,data=accdnt_All)
    plt.title(i,size=20)
    plt.ylabel('')
    plt.xlabel('')
plt.show()

# %% [markdown]
# #### Creating features and Predictive value

# %%
accdnt_All.drop('Junction_Detail', axis=1)
accdnt_All.fillna('Unknown')
# Out:
#         Accident_Index Location_Easting_OSGR Location_Northing_OSGR Longitude  \
# 0        200501BS00001                525680                 178240  -0.19117
# 1        200501BS00002                524170                 181650 -0.211708
# 2        200501BS00003                524520                 182240 -0.206458
# 3        200501BS00004                526900                 177530 -0.173862
# 4        200501BS00005                528060                 179040 -0.156618
# 5        200501BS00006                524770                 181160 -0.203238
# 6        200501BS00007                524220                 180830 -0.211277
# 7        200501BS00009                525890                 179710 -0.187623
# 8        200501BS00010                527350                 177650 -0.167342
# 9        200501BS00011                524550                 180810 -0.206531
# 10       200501BS00012                526240                 178900 -0.182872
# ...

# %%
PolArr_raw = accdnt_All['Did_Police_Officer_Attend_Scene_of_Accident']
Feature_raw = accdnt_All.drop(['Did_Police_Officer_Attend_Scene_of_Accident','Accident_Index','Date',
                               'Time','Location_Easting_OSGR','Location_Northing_OSGR','Year',
                              '1st_Road_Number','2nd_Road_Number','Longitude','Latitude','LSOA_of_Accident_Location','Junction_Detail'], axis=1)

# %%
Feature_raw.dtypes
# Out:
# Police_Force                                int64
# Accident_Severity                           int64
# Number_of_Vehicles                          int64
# Number_of_Casualties                        int64
# Day_of_Week                                 int64
# Local_Authority_(District)                  int64
# Local_Authority_(Highway)                  object
# 1st_Road_Class                              int64
# Road_Type                                  object
# Speed_limit                                 int64
# Junction_Control                           object
# 2nd_Road_Class                              int64
# Pedestrian_Crossing-Human_Control          object
# Pedestrian_Crossing-Physical_Facilities    object
# Light_Conditions                           object
# Weather_Conditions                         object
# Road_Surface_Conditions                    object
# Special_Conditions_at_Site                 object
# Carriageway_Hazards                        object
# ...

# %% [markdown]
# #### Data Preprocessing

# %% [markdown]
# ##### One HotEncoder

# %%
# One hot encode using pandas.dummies
Feature_final = pd.get_dummies(Feature_raw)

#Encode Police Arrival data to numerical value
PolArr_final = pd.get_dummies(PolArr_raw, drop_first=True)

encoded = list(Feature_final.columns)

print("{} total features after one hot encoding" .format(len(encoded)))
# Out:
# 269 total features after one hot encoding

# %% [markdown]
# #### Shuffle and Split

# %%
#Import train test split
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(Feature_final, 
                                                    PolArr_final, 
                                                    test_size = 0.2, 
                                                    random_state = 0)

#Show the result for split
print("Training set has {} as samples" .format(X_train.shape[0]))
print("Testing set has {} as samples" .format(X_test.shape[0]))
print("Training y set has {} as samples" .format(y_train.shape[0]))
print("Testing y set has {} as samples" .format(y_test.shape[0]))
# Out:
# Training set has 1203320 as samples
# Training set has 300830 as samples

# %% [markdown]
# #### Performance Calculation

# %%
from sklearn.metrics import fbeta_score, accuracy_score, confusion_matrix
def claf_performance(test_val, pred_val, model):
    from sklearn.metrics import fbeta_score, accuracy_score, confusion_matrix
    
    tn, fp, fn, tp = confusion_matrix(test_val, pred_val).ravel()
    acc = accuracy_score(test_val, pred_val)
    fbeta = fbeta_score(test_val, pred_val, beta=0.5)
    print("Total number of {} are True Negative".format(tn))
    print("Total number of {} are False Positive".format(fp))
    print("Total number of {} are False Negative".format(fn))
    print("Total number of {} are True Positive".format(tp))
    print("{}".format(model))
    print("Accuracy Score for model: {:.3f}".format(acc))
    print("Beta Score for model for beat=0.5: {:.3f}".format(fbeta))
    return

# %% [markdown]
# ### Benchmark Model

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

claf = LogisticRegression()
claf.fit(X_train, y_train)

clf_pred =claf.predict(X_test)
claf_performance(y_test, clf_pred, claf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Total number of 3390 are True Negative
# Total number of 53680 are False Positive
# Total number of 1882 are False Negative
# Total number of 241878 are True Positive
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Accuracy Score for model: 0.815
# Beta Score for model for beat=0.5: 0.848

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# #### Grid Search Using Kfold

# %%
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer

def GridSearch_Classifier(classifier,parameters, splits_count, X_train, y_train):
    
    scorer = make_scorer(fbeta_score, beta=0.5)
    kfold = KFold(n_splits=splits_count, shuffle=True, random_state=0)
    
    grid_obj = GridSearchCV(classifier,parameters, scoring = scorer, cv = kfold)
    
    grid_fit = grid_obj.fit(X_train, y_train)
    
    print(grid_fit.cv_results_)
    
    return grid_fit

# %% [markdown]
# #### SVM

# %%
'''
from sklearn.svm import SVC

claf = SVC(kernel='rbf', random_state=0)
claf.fit(X_train, y_train)

clf_pred =claf.predict(X_test)
claf_performance(y_test, clf_pred, claf)
'''
# Out:
# "\nfrom sklearn.svm import SVC\n\nclaf = SVC(kernel='rbf', random_state=0)\nclaf.fit(X_train, y_train)\n\nclf_pred =claf.predict(X_test)\nclaf_performance(y_test, clf_pred, claf)\n"

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

claf = GaussianNB()
claf.fit(X_train, y_train)

clf_pred =claf.predict(X_test)
claf_performance(y_test, clf_pred, claf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Total number of 46420 are True Negative
# Total number of 10650 are False Positive
# Total number of 149556 are False Negative
# Total number of 94204 are True Positive
# GaussianNB(priors=None)
# Accuracy Score for model: 0.467
# Beta Score for model for beat=0.5: 0.710

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

claf = DecisionTreeClassifier(criterion='entropy',random_state=0)
claf.fit(X_train, y_train)

clf_pred =claf.predict(X_test)
claf_performance(y_test, clf_pred, claf)
# Out:
# Total number of 18014 are True Negative
# Total number of 39056 are False Positive
# Total number of 38501 are False Negative
# Total number of 205259 are True Positive
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')
# Accuracy Score for model: 0.742
# Beta Score for model for beat=0.5: 0.841

# %% [markdown]
# #### Optimized Decision Tree

# %%
param = {}
data_split_nbr = 10

Opt_clf = GridSearch_Classifier(claf, param, data_split_nbr, X_train, y_train )

best_clf = Opt_clf.best_estimator_
best_predictions = best_clf.predict(X_test)
claf_performance(y_test, best_predictions, best_clf)
# Out:
# {'mean_fit_time': array([88.7418925]), 'std_fit_time': array([1.94394743]), 'mean_score_time': array([0.32814119]), 'std_score_time': array([0.01397777]), 'params': [{}], 'split0_test_score': array([0.84073377]), 'split1_test_score': array([0.8398842]), 'split2_test_score': array([0.83962932]), 'split3_test_score': array([0.83916062]), 'split4_test_score': array([0.83957178]), 'split5_test_score': array([0.83950969]), 'split6_test_score': array([0.84064206]), 'split7_test_score': array([0.8402426]), 'split8_test_score': array([0.84058155]), 'split9_test_score': array([0.83940063]), 'mean_test_score': array([0.83993562]), 'std_test_score': array([0.00054265]), 'rank_test_score': array([1]), 'split0_train_score': array([0.96046057]), 'split1_train_score': array([0.96049583]), 'split2_train_score': array([0.96050015]), 'split3_train_score': array([0.96044604]), 'split4_train_score': array([0.96035702]), 'split5_train_score': array([0.96050298]), 'split6_train_score': array([0.96030857])
# ...

# %%
best_clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

claf = RandomForestClassifier()
claf.fit(X_train, y_train)

clf_pred =claf.predict(X_test)
claf_performance(y_test, clf_pred, claf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# Total number of 14055 are True Negative
# Total number of 43015 are False Positive
# Total number of 22709 are False Negative
# Total number of 221051 are True Positive
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# Accuracy Score for model: 0.782
# Beta Score for model for beat=0.5: 0.850

# %% [markdown]
# #### Optimized Random Forest

# %%
param = {'n_estimators': [5, 10, 15, 20, 25]}
data_split_nbr = 10

Opt_clf = GridSearch_Classifier(claf, param, data_split_nbr, X_train, y_train )

best_clf = Opt_clf.best_estimator_
best_predictions = best_clf.predict(X_test)
claf_performance(y_test, best_predictions, best_clf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
best_clf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=25, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# #### K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

claf=KNeighborsClassifier()

claf.fit(X_train, y_train)

clf_pred =claf.predict(X_test)
claf_performance(y_test, clf_pred, claf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """
# Total number of 10428 are True Negative
# Total number of 46642 are False Positive
# Total number of 19069 are False Negative
# Total number of 224691 are True Positive
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')
# Accuracy Score for model: 0.782
# Beta Score for model for beat=0.5: 0.845

# %% [markdown]
# ### Multi Layer Perceptrom

# %%
from sklearn.neural_network import MLPClassifier

claf=MLPClassifier()

claf.fit(X_train, y_train)

clf_pred =claf.predict(X_test)
claf_performance(y_test, clf_pred, claf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:912: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Total number of 4635 are True Negative
# Total number of 52435 are False Positive
# Total number of 2813 are False Negative
# Total number of 240947 are True Positive
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Accuracy Score for model: 0.816
# Beta Score for model for beat=0.5: 0.850
