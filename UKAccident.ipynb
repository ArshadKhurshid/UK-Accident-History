# %% [markdown]
# # UK Accident History

# %% [markdown]
# ## Data Import

# %% [markdown]
# ### Package Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import CSV files

# %%
accdnt_2005 = pd.read_csv('accidents_2005_to_2007.csv')
accdnt_2009 = pd.read_csv('accidents_2009_to_2011.csv')
accdnt_2012 = pd.read_csv('accidents_2012_to_2014.csv')
accdntTraffic = pd.read_csv('ukTrafficAADF.csv')
# Out:
# C:\Users\Arshad\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accdnt_2005.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    Number_of_Casualties        Date  ...   \
# 0                     1  04/01/2005  ...
# ...

# %%
accdnt_2009.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200901BS70001                 524910                  180800  -0.201349
# 1  200901BS70002                 525050                  181040  -0.199248
# 2  200901BS70003                 526490                  177990  -0.179599
# 3  200901BS70004                 524800                  180300  -0.203110
# 4  200901BS70005                 526930                  177490  -0.173445
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.512273             1                  2                   2
# 1  51.514399             1                  2                   2
# 2  51.486668             1                  3                   2
# 3  51.507804             1                  2                   2
# 4  51.482076             1                  2                   2
#
#    Number_of_Casualties        Date  ...   \
# 0                     1  01/01/2009  ...
# ...

# %%
accdnt_2012.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...   \
# 0                     1  19/01/2012  ...
# ...

# %%
accdntTraffic.head()
# Out:
#    AADFYear    CP Estimation_method Estimation_method_detailed  \
# 0      2000  6007           Counted               Manual count
# 1      2000  6009           Counted               Manual count
# 2      2000  6035           Counted               Manual count
# 3      2000  6054           Counted               Manual count
# 4      2000  6055           Counted               Manual count
#
#                      Region LocalAuthority  Road RoadCategory  Easting  \
# 0  Yorkshire and the Humber      Rotherham    M1           TM   446000
# 1  Yorkshire and the Humber          Leeds  M621           TM   432150
# 2  Yorkshire and the Humber      Doncaster   M18           TM   466400
# 3  Yorkshire and the Humber     Calderdale   M62           TM   404000
# 4  Yorkshire and the Humber          Leeds   M62           TM   426000
#
#    Northing    ...    V2AxleRigidHGV V3AxleRigidHGV  V4or5AxleRigidHGV  \
# 0    389300    ...              5351            656                711
# ...

# %% [markdown]
# #### Columns specification

# %%
print(accdnt_2005.columns)
print(accdnt_2009.columns)
print(accdnt_2012.columns)
print(accdntTraffic.columns)
# Out:
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Year'],
#       dtype='object')
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
# ...

# %% [markdown]
# #### Merge year dataset to one

# %%
accdnt_All = pd.concat([accdnt_2005,accdnt_2009,accdnt_2012], ignore_index=True)
#accdnt_All.head()
print(accdnt_All.shape)
print(accdnt_2005.shape)
print(accdnt_2009.shape)
print(accdnt_2012.shape)
# Out:
# (1504150, 33)
# (570011, 33)
# (469442, 33)
# (464697, 33)

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# #### Urban vs Rural

# %%
UrbanRural = accdnt_All['Urban_or_Rural_Area'].value_counts()
UrbanRural.plot.pie(figsize=(8,8))
plt.show()

# %%
sns.barplot(x=UrbanRural.index, y=UrbanRural.values)
plt.xlabel('Rural or Urban')
plt.ylabel('Accident count')
plt.show()

# %% [markdown]
# #### Pie  Chart on Light Condition

# %%
lightCondition = accdnt_All['Light_Conditions'].value_counts()
lightCondition.plot.pie(figsize=(8,8))
plt.show()

# %%
f, ax = plt.subplots(figsize=(17,8))
sns.barplot(x=lightCondition.index, y=lightCondition.values,ax=ax)
plt.xlabel('Light Condition')
plt.ylabel('Accident count')
plt.show()

# %% [markdown]
# #### Year Wise accident Analysis

# %%
year = accdnt_All['Year'].value_counts()
year.plot.pie(figsize=(8,8))
plt.show()

# %%
f,ax = plt.subplots(figsize=(15, 8))
sns.barplot(x=year.index, y=year.values, ax=ax)
plt.xlabel('')
plt.ylabel('')
plt.show()
